# %%
# load Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns
from  pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/susan/battery_materials_ml/data/insertion_electrodes.csv')
df.head()
data = df.copy()
print(df['battery_type'].unique())
print(data["thermo_type"].isna().sum())
# Out:
# ['insertion']
# 4103

# %%
print(data.columns)
print()
print("="*50)
data.head(5)
# Out:
# Index(['builder_meta', 'battery_type', 'material_ids', 'thermo_type',
#        'battery_formula', 'working_ion', 'num_steps', 'max_voltage_step',
#        'last_updated', 'framework', 'framework_formula', 'elements',
#        'nelements', 'chemsys', 'formula_anonymous', 'warnings',
#        'formula_charge', 'formula_discharge', 'max_delta_volume',
#        'average_voltage', 'capacity_grav', 'capacity_vol', 'energy_grav',
#        'energy_vol', 'fracA_charge', 'fracA_discharge', 'stability_charge',
#        'stability_discharge', 'id_charge', 'id_discharge', 'host_structure',
#        'adj_pairs', 'entries_composition_summary', 'electrode_object'],
#       dtype='object')
#
# ...
#                                         builder_meta battery_type  \
# 0  {'emmet_version': '0.86.4rc1.dev71+g64b11f337....    insertion
# 1  {'emmet_version': '0.86.4rc1.dev71+g64b11f337....    insertion
# 2  {'emmet_version': '0.86.4rc1.dev71+g64b11f337....    insertion
# ...

# %%
# EDA data 
data.drop(columns=['builder_meta','battery_type', 'thermo_type' ,'id_charge', 'id_discharge', 'host_structure',
       'adj_pairs', 'entries_composition_summary', 'last_updated','electrode_object'], errors ='ignore', inplace=True)
print()
print("="*50)

# %%
print(data.info())
print()
print("="*50)
data[["battery_formula", "nelements", "chemsys"]].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4103 entries, 0 to 4102
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   material_ids         4103 non-null   object
#  1   battery_formula      4103 non-null   object
#  2   working_ion          4103 non-null   object
#  3   num_steps            4103 non-null   int64
#  4   max_voltage_step     4103 non-null   float64
#  5   framework            4103 non-null   object
#  6   framework_formula    4103 non-null   object
#  7   elements             4103 non-null   object
#  8   nelements            4103 non-null   int64
#  9   chemsys              4103 non-null   object
#  10  formula_anonymous    4103 non-null   object
#  11  warnings             4103 non-null   object
#  12  formula_charge       4103 non-null   object
#  13  formula_discharge    4103 non-null   object
#  14  max_delta_volume     4103 non-null   float64
# ...
